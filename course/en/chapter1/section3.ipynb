# %% [markdown]
# # Intor to LLM

# %%
# Kifurushi kikuu cha kozi ya Hugging Face
# !pip install transformers datasets evaluate accelerate -q

# %%
from transformers import pipeline
classifier=pipeline("zero-shot-classification")
classifier (
    "llm course simply focus on understanding large ai model",
    candidate_labels=["education","sport","politics"],
)
# Out:
# [transformers] No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# {'sequence': 'llm course simply focus on understanding large ai model',
#  'labels': ['education', 'sport', 'politics'],
#  'scores': [0.7707295417785645, 0.13026073575019836, 0.0990096926689148]}
